# %% [markdown]
# <a href="https://colab.research.google.com/github/ufrpe-mineracao-textos/projeto-de-mineracao-20192-traducao-de-texto/blob/master/preprocessamento/PreprocessingTextMining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f6dcc51e-1ffe-40e9-81c3-367d33d1b580" name="files[]" multiple disabled />
#      <output id="result-f6dcc51e-1ffe-40e9-81c3-367d33d1b580">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving subtextdata.csv to subtextdata.csv

# %%
import spacy
import os
from nltk.stem import PorterStemmer 
from nltk.tokenize import word_tokenize
import nltk
import pandas as pd

nltk.download('punkt')
ps = PorterStemmer()
data = pd.read_csv("/content/subtextdata.csv") # ajustar o caminho de acordo com o nome do arquivo upado
data
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Loading

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# # Text

# %%
#text = "A US official told CNN on Sunday that US Central Command will determine the pace of the withdrawal and it will not happen immediately, but will take place deliberately and could take days to weeks.This is a withdrawal plan that was drawn up in February, in case an order was given to pull out American troops, however it is being implemented at a much faster pace than planned.US troops still on the ground and on the move are receiving military air cover. A source familiar with operations in Syria told CNN that if there is an unauthorized approach on US positions, the American side will first attempt to de-escalate, and if their efforts fail, they are authorized to use deadly force to repel any threat -- whether that is from Turkish forces advancing into Syria or other actors already involved in the Syrian civil war.Esper did not initially make it entirely clear whether the withdrawal would mean the US troops would be leaving Syria entirely or relocating elsewhere in the country away from where Turkish forces are operating. The Pentagon did not respond to CNN's request Sunday for clarification on the troop withdrawal.While the majority of the 1,000 US troops in Syria are in the northern part of the country, the US military also maintains a small presence in southern Syria at a base in At Tanf where the US trains local anti-ISIS fighters that are not affiliated with the Syrian Democratic Forces.A US official familiar with the situation on the ground said earlier Sunday that US forces in Syria are preparing to withdraw from the country.The official said the situation on the ground is deteriorating rapidly in northeast Syria, adding that Turkish proxies, which the official describes as including extremists, have advanced along the strategically important M4 highway setting up multiple checkpoints. He says these proxy forces are wearing SDF uniforms and killing civilians on the highway. US Forces and SDF troops no longer control ground lines of communication and have no control over Turkish aircraft overhead.US Forces are at risk of being isolated and there is increased risk of confrontation between Turkish proxies and US Forces unless Turkey halts their advance immediately, the official says."
text = pd.Series(data["Text"])
text = text.str.cat(sep=' ')
doc = nlp(text)
words = word_tokenize(text)

# %% [markdown]
# Tokenização

# %%
for token in doc:
    print("{0}\t{1}\t{2}\t{3}".format(
        token.text,
        token.lemma_,
        token.is_stop,
        token.pos_
    ))
# Out:
# A	a	True	DET
# US	US	True	PROPN
# official	official	False	NOUN
# told	tell	False	VERB
# CNN	CNN	False	PROPN
# on	on	True	ADP
# Sunday	Sunday	False	PROPN
# that	that	True	ADP
# US	US	True	PROPN
# Central	Central	False	PROPN
# Command	Command	False	PROPN
# will	will	True	VERB
# determine	determine	False	VERB
# the	the	True	DET
# pace	pace	False	NOUN
# of	of	True	ADP
# the	the	True	DET
# withdrawal	withdrawal	False	NOUN
# and	and	True	CCONJ
# it	-PRON-	True	PRON
# will	will	True	VERB
# not	not	True	ADV
# happen	happen	False	VERB
# immediately	immediately	False	ADV
# ,	,	False	PUNCT
# but	but	True	CCONJ
# will	will	True	VERB
# take	take	True	VERB
# place	place	False	NOUN
# deliberately	deliberately	False	ADV
# and	and	True	CCONJ
# could	could	True	VERB
# take	take	True	VERB
# days	day	False	NOUN
# to	to	True	ADP
# weeks	week	False	NOUN
# .	.	False	PUNCT
# This	this	True	DET
# is	be	True	VERB
# a	a	True	DET
# withdrawal	withdrawal	False	NOUN
# plan	plan	False	NOUN
# that	that	True	DET
# was	be	True	VERB
# drawn	draw	False	VERB
# up	up	True	PART
# in	in	True	ADP
# February	February	False	PROPN
# ,	,	False	PUNCT
# in	in	True	ADP
# case	case	False	NOUN
# an	an	True	DET
# order	order	False	NOUN
# was	be	True	VERB
# given	give	False	VERB
# to	to	True	PART
# pull	pull	False	VERB
# out	out	True	PART
# American	american	False	ADJ
# troops	troop	False	NOUN
# ,	,	False	PUNCT
# however	however	True	ADV
# it	-PRON-	True	PRON
# is	be	True	VERB
# being	be	True	VERB
# implemented	implement	False	VERB
# at	at	True	ADP
# a	a	True	DET
# much	much	True	ADV
# faster	fast	False	ADJ
# pace	pace	False	NOUN
# than	than	True	ADP
# planned	plan	False	VERB
# .	.	False	PUNCT
# US	US	True	PROPN
# troops	troop	False	NOUN
# still	still	True	ADV
# on	on	True	ADP
# the	the	True	DET
# ground	ground	False	NOUN
# and	and	True	CCONJ
# on	on	True	ADP
# the	the	True	DET
# move	move	True	NOUN
# are	be	True	VERB
# receiving	receive	False	VERB
# military	military	False	ADJ
# air	air	False	NOUN
# cover	cover	False	NOUN
# .	.	False	PUNCT
# A	a	True	DET
# source	source	False	NOUN
# familiar	familiar	False	ADJ
# with	with	True	ADP
# operations	operation	False	NOUN
# in	in	True	ADP
# Syria	Syria	False	PROPN
# told	tell	False	VERB
# CNN	CNN	False	PROPN
# that	that	True	ADP
# if	if	True	ADP
# there	there	True	ADV
# is	be	True	VERB
# an	an	True	DET
# unauthorized	unauthorized	False	ADJ
# approach	approach	False	NOUN
# on	on	True	ADP
# US	US	True	PROPN
# positions	position	False	NOUN
# ,	,	False	PUNCT
# the	the	True	DET
# American	american	False	ADJ
# side	side	True	NOUN
# will	will	True	VERB
# first	first	True	ADV
# attempt	attempt	False	VERB
# to	to	True	ADP
# de	de	False	ADJ
# -	-	False	NOUN
# escalate	escalate	False	NOUN
# ,	,	False	PUNCT
# and	and	True	CCONJ
# if	if	True	ADP
# their	-PRON-	True	DET
# efforts	effort	False	NOUN
# fail	fail	False	VERB
# ,	,	False	PUNCT
# they	-PRON-	True	PRON
# are	be	True	VERB
# authorized	authorize	False	VERB
# to	to	True	PART
# use	use	False	VERB
# deadly	deadly	False	ADJ
# force	force	False	NOUN
# to	to	True	PART
# repel	repel	False	VERB
# any	any	True	DET
# threat	threat	False	NOUN
# --	--	False	PUNCT
# whether	whether	True	ADP
# that	that	True	DET
# is	be	True	VERB
# from	from	True	ADP
# Turkish	turkish	False	ADJ
# forces	force	False	NOUN
# advancing	advance	False	VERB
# into	into	True	ADP
# Syria	Syria	False	PROPN
# or	or	True	CCONJ
# other	other	True	ADJ
# actors	actor	False	NOUN
# already	already	True	ADV
# involved	involve	False	VERB
# in	in	True	ADP
# the	the	True	DET
# Syrian	syrian	False	ADJ
# civil	civil	False	ADJ
# war	war	False	NOUN
# .	.	False	PUNCT
# Esper	Esper	False	PROPN
# did	do	True	VERB
# not	not	True	ADV
# initially	initially	False	ADV
# make	make	True	VERB
# it	-PRON-	True	PRON
# entirely	entirely	False	ADV
# clear	clear	False	ADJ
# whether	whether	True	ADP
# the	the	True	DET
# withdrawal	withdrawal	False	NOUN
# would	would	True	VERB
# mean	mean	False	VERB
# the	the	True	DET
# US	US	True	PROPN
# troops	troop	False	NOUN
# would	would	True	VERB
# be	be	True	VERB
# leaving	leave	False	VERB
# Syria	Syria	False	PROPN
# entirely	entirely	False	ADV
# or	or	True	CCONJ
# relocating	relocate	False	VERB
# elsewhere	elsewhere	True	ADV
# in	in	True	ADP
# the	the	True	DET
# country	country	False	NOUN
# away	away	False	ADV
# from	from	True	ADP
# where	where	True	ADV
# Turkish	turkish	False	ADJ
# forces	force	False	NOUN
# are	be	True	VERB
# operating	operate	False	VERB
# .	.	False	PUNCT
# The	the	True	DET
# Pentagon	Pentagon	False	PROPN
# did	do	True	VERB
# not	not	True	ADV
# respond	respond	False	VERB
# to	to	True	ADP
# CNN	CNN	False	PROPN
# 's	's	True	PART
# request	request	False	NOUN
# Sunday	Sunday	False	PROPN
# for	for	True	ADP
# clarification	clarification	False	NOUN
# on	on	True	ADP
# the	the	True	DET
# troop	troop	False	NOUN
# withdrawal	withdrawal	False	NOUN
# .	.	False	PUNCT
# While	while	True	ADP
# the	the	True	DET
# majority	majority	False	NOUN
# of	of	True	ADP
# the	the	True	DET
# 1,000	1,000	False	NUM
# US	US	True	PROPN
# troops	troop	False	NOUN
# in	in	True	ADP
# Syria	Syria	False	PROPN
# are	be	True	VERB
# in	in	True	ADP
# the	the	True	DET
# northern	northern	False	ADJ
# part	part	True	NOUN
# of	of	True	ADP
# the	the	True	DET
# country	country	False	NOUN
# ,	,	False	PUNCT
# the	the	True	DET
# US	US	True	PROPN
# military	military	False	NOUN
# also	also	True	ADV
# maintains	maintain	False	VERB
# a	a	True	DET
# small	small	False	ADJ
# presence	presence	False	NOUN
# in	in	True	ADP
# southern	southern	False	ADJ
# Syria	Syria	False	PROPN
# at	at	True	ADP
# a	a	True	DET
# base	base	False	NOUN
# in	in	True	ADP
# At	at	True	ADP
# Tanf	Tanf	False	PROPN
# where	where	True	ADV
# the	the	True	DET
# US	US	True	PROPN
# trains	train	False	VERB
# local	local	False	ADJ
# anti	anti	False	ADJ
# -	-	False	ADJ
# ISIS	isis	False	ADJ
# fighters	fighter	False	NOUN
# that	that	True	DET
# are	be	True	VERB
# not	not	True	ADV
# affiliated	affiliate	False	VERB
# with	with	True	ADP
# the	the	True	DET
# Syrian	syrian	False	ADJ
# Democratic	democratic	False	ADJ
# Forces	Forces	False	PROPN
# .	.	False	PUNCT
# A	a	True	DET
# US	US	True	PROPN
# official	official	False	NOUN
# familiar	familiar	False	ADJ
# with	with	True	ADP
# the	the	True	DET
# situation	situation	False	NOUN
# on	on	True	ADP
# the	the	True	DET
# ground	ground	False	NOUN
# said	say	False	VERB
# earlier	earlier	False	ADV
# Sunday	Sunday	False	PROPN
# that	that	True	ADP
# US	US	True	PROPN
# forces	force	False	NOUN
# in	in	True	ADP
# Syria	Syria	False	PROPN
# are	be	True	VERB
# preparing	prepare	False	VERB
# to	to	True	PART
# withdraw	withdraw	False	VERB
# from	from	True	ADP
# the	the	True	DET
# country	country	False	NOUN
# .	.	False	PUNCT
# The	the	True	DET
# official	official	False	NOUN
# said	say	False	VERB
# the	the	True	DET
# situation	situation	False	NOUN
# on	on	True	ADP
# the	the	True	DET
# ground	ground	False	NOUN
# is	be	True	VERB
# deteriorating	deteriorate	False	VERB
# rapidly	rapidly	False	ADV
# in	in	True	ADP
# northeast	northeast	False	ADJ
# Syria	Syria	False	PROPN
# ,	,	False	PUNCT
# adding	add	False	VERB
# that	that	True	ADP
# Turkish	turkish	False	ADJ
# proxies	proxy	False	NOUN
# ,	,	False	PUNCT
# which	which	True	DET
# the	the	True	DET
# official	official	False	NOUN
# describes	describe	False	VERB
# as	as	True	ADP
# including	include	False	VERB
# extremists	extremist	False	NOUN
# ,	,	False	PUNCT
# have	have	True	VERB
# advanced	advance	False	VERB
# along	along	True	ADP
# the	the	True	DET
# strategically	strategically	False	ADV
# important	important	False	ADJ
# M4	M4	False	PROPN
# highway	highway	False	NOUN
# setting	set	False	VERB
# up	up	True	PART
# multiple	multiple	False	ADJ
# checkpoints	checkpoint	False	NOUN
# .	.	False	PUNCT
# He	-PRON-	True	PRON
# says	say	False	VERB
# these	these	True	DET
# proxy	proxy	False	ADJ
# forces	force	False	NOUN
# are	be	True	VERB
# wearing	wear	False	VERB
# SDF	SDF	False	PROPN
# uniforms	uniform	False	NOUN
# and	and	True	CCONJ
# killing	kill	False	VERB
# civilians	civilian	False	NOUN
# on	on	True	ADP
# the	the	True	DET
# highway	highway	False	NOUN
# .	.	False	PUNCT
# US	US	True	PROPN
# Forces	Forces	False	PROPN
# and	and	True	CCONJ
# SDF	SDF	False	PROPN
# troops	troop	False	NOUN
# no	no	True	ADV
# longer	longer	False	ADV
# control	control	False	VERB
# ground	ground	False	NOUN
# lines	line	False	NOUN
# of	of	True	ADP
# communication	communication	False	NOUN
# and	and	True	CCONJ
# have	have	True	VERB
# no	no	True	DET
# control	control	False	NOUN
# over	over	True	ADP
# Turkish	turkish	False	ADJ
# aircraft	aircraft	False	NOUN
# overhead	overhead	False	ADV
# .	.	False	PUNCT
# US	US	True	PROPN
# Forces	Forces	False	PROPN
# are	be	True	VERB
# at	at	True	ADP
# risk	risk	False	NOUN
# of	of	True	ADP
# being	be	True	VERB
# isolated	isolate	False	VERB
# and	and	True	CCONJ
# there	there	True	ADV
# is	be	True	VERB
# increased	increase	False	VERB
# risk	risk	False	NOUN
# of	of	True	ADP
# confrontation	confrontation	False	NOUN
# between	between	True	ADP
# Turkish	turkish	False	ADJ
# proxies	proxy	False	NOUN
# and	and	True	CCONJ
# US	US	True	PROPN
# Forces	Forces	False	PROPN
# unless	unless	True	ADP
# Turkey	Turkey	False	PROPN
# halts	halt	False	VERB
# their	-PRON-	True	DET
# advance	advance	False	NOUN
# immediately	immediately	False	ADV
# ,	,	False	PUNCT
# the	the	True	DET
# official	official	False	NOUN
# says	say	False	VERB
# .	.	False	PUNCT

# %% [markdown]
# # Stemming

# %%
for word in words:
  print(word, " : ", ps.stem(word))
# Out:
# A  :  A
# US  :  US
# official  :  offici
# told  :  told
# CNN  :  cnn
# on  :  on
# Sunday  :  sunday
# that  :  that
# US  :  US
# Central  :  central
# Command  :  command
# will  :  will
# determine  :  determin
# the  :  the
# pace  :  pace
# of  :  of
# the  :  the
# withdrawal  :  withdraw
# and  :  and
# it  :  it
# will  :  will
# not  :  not
# happen  :  happen
# immediately  :  immedi
# ,  :  ,
# but  :  but
# will  :  will
# take  :  take
# place  :  place
# deliberately  :  deliber
# and  :  and
# could  :  could
# take  :  take
# days  :  day
# to  :  to
# weeks.This  :  weeks.thi
# is  :  is
# a  :  a
# withdrawal  :  withdraw
# plan  :  plan
# that  :  that
# was  :  wa
# drawn  :  drawn
# up  :  up
# in  :  in
# February  :  februari
# ,  :  ,
# in  :  in
# case  :  case
# an  :  an
# order  :  order
# was  :  wa
# given  :  given
# to  :  to
# pull  :  pull
# out  :  out
# American  :  american
# troops  :  troop
# ,  :  ,
# however  :  howev
# it  :  it
# is  :  is
# being  :  be
# implemented  :  implement
# at  :  at
# a  :  a
# much  :  much
# faster  :  faster
# pace  :  pace
# than  :  than
# planned.US  :  planned.u
# troops  :  troop
# still  :  still
# on  :  on
# the  :  the
# ground  :  ground
# and  :  and
# on  :  on
# the  :  the
# move  :  move
# are  :  are
# receiving  :  receiv
# military  :  militari
# air  :  air
# cover  :  cover
# .  :  .
# A  :  A
# source  :  sourc
# familiar  :  familiar
# with  :  with
# operations  :  oper
# in  :  in
# Syria  :  syria
# told  :  told
# CNN  :  cnn
# that  :  that
# if  :  if
# there  :  there
# is  :  is
# an  :  an
# unauthorized  :  unauthor
# approach  :  approach
# on  :  on
# US  :  US
# positions  :  posit
# ,  :  ,
# the  :  the
# American  :  american
# side  :  side
# will  :  will
# first  :  first
# attempt  :  attempt
# to  :  to
# de-escalate  :  de-escal
# ,  :  ,
# and  :  and
# if  :  if
# their  :  their
# efforts  :  effort
# fail  :  fail
# ,  :  ,
# they  :  they
# are  :  are
# authorized  :  author
# to  :  to
# use  :  use
# deadly  :  deadli
# force  :  forc
# to  :  to
# repel  :  repel
# any  :  ani
# threat  :  threat
# --  :  --
# whether  :  whether
# that  :  that
# is  :  is
# from  :  from
# Turkish  :  turkish
# forces  :  forc
# advancing  :  advanc
# into  :  into
# Syria  :  syria
# or  :  or
# other  :  other
# actors  :  actor
# already  :  alreadi
# involved  :  involv
# in  :  in
# the  :  the
# Syrian  :  syrian
# civil  :  civil
# war.Esper  :  war.esp
# did  :  did
# not  :  not
# initially  :  initi
# make  :  make
# it  :  it
# entirely  :  entir
# clear  :  clear
# whether  :  whether
# the  :  the
# withdrawal  :  withdraw
# would  :  would
# mean  :  mean
# the  :  the
# US  :  US
# troops  :  troop
# would  :  would
# be  :  be
# leaving  :  leav
# Syria  :  syria
# entirely  :  entir
# or  :  or
# relocating  :  reloc
# elsewhere  :  elsewher
# in  :  in
# the  :  the
# country  :  countri
# away  :  away
# from  :  from
# where  :  where
# Turkish  :  turkish
# forces  :  forc
# are  :  are
# operating  :  oper
# .  :  .
# The  :  the
# Pentagon  :  pentagon
# did  :  did
# not  :  not
# respond  :  respond
# to  :  to
# CNN  :  cnn
# 's  :  's
# request  :  request
# Sunday  :  sunday
# for  :  for
# clarification  :  clarif
# on  :  on
# the  :  the
# troop  :  troop
# withdrawal.While  :  withdrawal.whil
# the  :  the
# majority  :  major
# of  :  of
# the  :  the
# 1,000  :  1,000
# US  :  US
# troops  :  troop
# in  :  in
# Syria  :  syria
# are  :  are
# in  :  in
# the  :  the
# northern  :  northern
# part  :  part
# of  :  of
# the  :  the
# country  :  countri
# ,  :  ,
# the  :  the
# US  :  US
# military  :  militari
# also  :  also
# maintains  :  maintain
# a  :  a
# small  :  small
# presence  :  presenc
# in  :  in
# southern  :  southern
# Syria  :  syria
# at  :  at
# a  :  a
# base  :  base
# in  :  in
# At  :  At
# Tanf  :  tanf
# where  :  where
# the  :  the
# US  :  US
# trains  :  train
# local  :  local
# anti-ISIS  :  anti-isi
# fighters  :  fighter
# that  :  that
# are  :  are
# not  :  not
# affiliated  :  affili
# with  :  with
# the  :  the
# Syrian  :  syrian
# Democratic  :  democrat
# Forces.A  :  forces.a
# US  :  US
# official  :  offici
# familiar  :  familiar
# with  :  with
# the  :  the
# situation  :  situat
# on  :  on
# the  :  the
# ground  :  ground
# said  :  said
# earlier  :  earlier
# Sunday  :  sunday
# that  :  that
# US  :  US
# forces  :  forc
# in  :  in
# Syria  :  syria
# are  :  are
# preparing  :  prepar
# to  :  to
# withdraw  :  withdraw
# from  :  from
# the  :  the
# country.The  :  country.th
# official  :  offici
# said  :  said
# the  :  the
# situation  :  situat
# on  :  on
# the  :  the
# ground  :  ground
# is  :  is
# deteriorating  :  deterior
# rapidly  :  rapidli
# in  :  in
# northeast  :  northeast
# Syria  :  syria
# ,  :  ,
# adding  :  ad
# that  :  that
# Turkish  :  turkish
# proxies  :  proxi
# ,  :  ,
# which  :  which
# the  :  the
# official  :  offici
# describes  :  describ
# as  :  as
# including  :  includ
# extremists  :  extremist
# ,  :  ,
# have  :  have
# advanced  :  advanc
# along  :  along
# the  :  the
# strategically  :  strateg
# important  :  import
# M4  :  M4
# highway  :  highway
# setting  :  set
# up  :  up
# multiple  :  multipl
# checkpoints  :  checkpoint
# .  :  .
# He  :  He
# says  :  say
# these  :  these
# proxy  :  proxi
# forces  :  forc
# are  :  are
# wearing  :  wear
# SDF  :  sdf
# uniforms  :  uniform
# and  :  and
# killing  :  kill
# civilians  :  civilian
# on  :  on
# the  :  the
# highway  :  highway
# .  :  .
# US  :  US
# Forces  :  forc
# and  :  and
# SDF  :  sdf
# troops  :  troop
# no  :  no
# longer  :  longer
# control  :  control
# ground  :  ground
# lines  :  line
# of  :  of
# communication  :  commun
# and  :  and
# have  :  have
# no  :  no
# control  :  control
# over  :  over
# Turkish  :  turkish
# aircraft  :  aircraft
# overhead.US  :  overhead.u
# Forces  :  forc
# are  :  are
# at  :  at
# risk  :  risk
# of  :  of
# being  :  be
# isolated  :  isol
# and  :  and
# there  :  there
# is  :  is
# increased  :  increas
# risk  :  risk
# of  :  of
# confrontation  :  confront
# between  :  between
# Turkish  :  turkish
# proxies  :  proxi
# and  :  and
# US  :  US
# Forces  :  forc
# unless  :  unless
# Turkey  :  turkey
# halts  :  halt
# their  :  their
# advance  :  advanc
# immediately  :  immedi
# ,  :  ,
# the  :  the
# official  :  offici
# says  :  say
# .  :  .

# %% [markdown]
# # NER

# %%
for ent in doc.ents:
   print(ent.text,ent.label_)
# Out:
# US GPE
# CNN ORG
# Sunday DATE
# US Central Command ORG
# days to weeks DATE
# February DATE
# American NORP
# US GPE
# Syria GPE
# CNN ORG
# US GPE
# American NORP
# first ORDINAL
# Turkish NORP
# Syria GPE
# Syrian NORP
# Esper ORG
# US GPE
# Syria GPE
# Turkish NORP
# Pentagon ORG
# CNN ORG
# Sunday DATE
# 1,000 CARDINAL
# US GPE
# Syria GPE
# US GPE
# Syria GPE
# Tanf GPE
# US GPE
# the Syrian Democratic Forces ORG
# US GPE
# earlier Sunday TIME
# US GPE
# Syria GPE
# Syria GPE
# Turkish NORP
# SDF ORG
# US GPE
# SDF ORG
# Turkish NORP
# US GPE
# Turkish NORP
# US Forces ORG
# Turkey GPE
